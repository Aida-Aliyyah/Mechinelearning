# %% [markdown]
# <a href="https://colab.research.google.com/github/Aida-Aliyyah/Mechinelearning/blob/main/Tugas_1_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
dataset = '/content/BBCA.JK.csv'
data = pd.read_csv (dataset)
data
# Out:
#             Date     Open     High      Low    Close     Adj Close      Volume
# 0     2004-06-08    875.0    900.0    875.0    887.5    438.253326  99830000.0
# 1     2004-06-09    887.5    912.5    875.0    900.0    444.425873  58858000.0
# 2     2004-06-10    900.0    900.0    887.5    900.0    444.425873  33118000.0
# 3     2004-06-11    887.5    900.0    887.5    900.0    444.425873  27166000.0
# 4     2004-06-14    900.0    900.0    875.0    887.5    438.253326  31708000.0
# ...          ...      ...      ...      ...      ...           ...         ...
# 3994  2020-06-29  28200.0  28475.0  27925.0  28375.0  28375.000000   9759300.0
# 3995  2020-06-30  28500.0  28700.0  28300.0  28475.0  28475.000000  14894800.0
# 3996  2020-07-01  28500.0  29000.0  28375.0  29000.0  29000.000000  12791800.0
# 3997  2020-07-02  28875.0  29350.0  28800.0  29350.0  29350.000000  15117100.0
# 3998  2020-07-03  29350.0  29525.0  29200.0  29350.0  29350.000000  10443800.0
#
# [3999 rows x 7 columns]
# ...

# %%
data.head()
# Out:
#          Date   Open   High    Low  Close   Adj Close      Volume
# 0  2004-06-08  875.0  900.0  875.0  887.5  438.253326  99830000.0
# 1  2004-06-09  887.5  912.5  875.0  900.0  444.425873  58858000.0
# 2  2004-06-10  900.0  900.0  887.5  900.0  444.425873  33118000.0
# 3  2004-06-11  887.5  900.0  887.5  900.0  444.425873  27166000.0
# 4  2004-06-14  900.0  900.0  875.0  887.5  438.253326  31708000.0

# %%
print(data.dtypes)
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume       float64
# dtype: object

# %%
datanoid = data.drop(data.columns[0],axis=1)

# %%
datanoid
# Out:
#          Open     High      Low    Close     Adj Close      Volume
# 0       875.0    900.0    875.0    887.5    438.253326  99830000.0
# 1       887.5    912.5    875.0    900.0    444.425873  58858000.0
# 2       900.0    900.0    887.5    900.0    444.425873  33118000.0
# 3       887.5    900.0    887.5    900.0    444.425873  27166000.0
# 4       900.0    900.0    875.0    887.5    438.253326  31708000.0
# ...       ...      ...      ...      ...           ...         ...
# 3994  28200.0  28475.0  27925.0  28375.0  28375.000000   9759300.0
# 3995  28500.0  28700.0  28300.0  28475.0  28475.000000  14894800.0
# 3996  28500.0  29000.0  28375.0  29000.0  29000.000000  12791800.0
# 3997  28875.0  29350.0  28800.0  29350.0  29350.000000  15117100.0
# 3998  29350.0  29525.0  29200.0  29350.0  29350.000000  10443800.0
#
# [3999 rows x 6 columns]

# %%
data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   3991.000000   3991.000000   3991.000000   3991.000000   3991.000000
# mean   10695.173515  10802.712353  10583.068153  10695.446004   9966.351151
# std     8719.402747   8789.391158   8647.344751   8715.297961   8665.579367
# min      875.000000    887.500000    875.000000    887.500000    438.253326
# 25%     3025.000000   3075.000000   2950.000000   3025.000000   2519.689087
# 50%     8000.000000   8100.000000   7950.000000   8000.000000   7125.761719
# 75%    14700.000000  14850.000000  14612.500000  14725.000000  13802.887695
# max    34750.000000  35300.000000  34175.000000  34375.000000  33790.851563
#
#              Volume
# count  3.991000e+03
# mean   2.259760e+07
# std    2.824364e+07
# min    0.000000e+00
# 25%    9.354500e+06
# 50%    1.452750e+07
# 75%    2.486400e+07
# max    3.899920e+08

# %%
data.loc[:,"High":].corr()
# Out:
#                High       Low     Close  Adj Close    Volume
# High       1.000000  0.999701  0.999827   0.999576 -0.276530
# Low        0.999701  1.000000  0.999857   0.999537 -0.279207
# Close      0.999827  0.999857  1.000000   0.999708 -0.277975
# Adj Close  0.999576  0.999537  0.999708   1.000000 -0.271181
# Volume    -0.276530 -0.279207 -0.277975  -0.271181  1.000000

# %% [markdown]
# Open Vs High

# %%
from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Open', y='High', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# Dengan Api

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

# Pastikan file kaggle.json sudah diunggah
if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-c9824ca0-7892-4176-a724-973ffabc30f0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c9824ca0-7892-4176-a724-973ffabc30f0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "Covid"
# Out:
# ...
# ref                                                title                                                size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# imdevskp/corona-virus-report                       COVID-19 Dataset                                     19MB  2020-08-07 03:47:47         304651       2265  1.0
# meirnizri/covid19-dataset                          COVID-19 Dataset                                      5MB  2022-11-13 15:47:17          42082        717  1.0
# sudalairajkumar/covid19-in-india                   COVID-19 in India                                   758KB  2021-08-11 04:14:10         232489       1961  0.9117647
# ...

# %%
# !kaggle datasets download -d imdevskp/corona-virus-report
# Out:
# ...
#  26% 5.00M/19.0M [00:00<00:00, 42.6MB/s]
# 100% 19.0M/19.0M [00:00<00:00, 116MB/s]

# %%
# !unzip /content/corona-virus-report.zip
# Out:
# Archive:  /content/corona-virus-report.zip
#   inflating: country_wise_latest.csv
#   inflating: covid_19_clean_complete.csv
#   inflating: day_wise.csv
#   inflating: full_grouped.csv
#   inflating: usa_county_wise.csv
#   inflating: worldometer_data.csv

# %%
pd.read_csv('/content/worldometer_data.csv')
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...
